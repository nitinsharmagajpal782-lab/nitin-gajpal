# %%
import pandas as pd

# %%
import numpy as nd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
Data = {
      "Name" : ["nitin","samridhi","alisha","barinder","arman"],
      "Maths" : [ 95,90,85,80,75],
    "Science" :  [85,92,68,65,92],
    "English" :  [80,95,88,85,75]
}

# %%
df = pd.DataFrame(Data)

# %%
df
# Out:
#        Name  Maths  Science  English
# 0     nitin     95       85       80
# 1  samridhi     90       92       95
# 2    alisha     85       68       88
# 3  barinder     80       65       85
# 4     arman     75       92       75

# %%
df["Total"]=df["Maths"]+df["Science"]+df["English"]
df["Average"] = df["Total"]/3

# %%
print(df)
# Out:
#        Name  Maths  Science  English  Total    Average
# 0     nitin     95       85       80    260  86.666667
# 1  samridhi     90       92       95    277  92.333333
# 2    alisha     85       68       88    241  80.333333
# 3  barinder     80       65       85    230  76.666667
# 4     arman     75       92       75    242  80.666667

# %%
df.isnull()
# Out:
#     Name  Maths  Science  English  Total  Average
# 0  False  False    False    False  False    False
# 1  False  False    False    False  False    False
# 2  False  False    False    False  False    False
# 3  False  False    False    False  False    False
# 4  False  False    False    False  False    False

# %%
df.notnull()
# Out:
#    Name  Maths  Science  English  Total  Average
# 0  True   True     True     True   True     True
# 1  True   True     True     True   True     True
# 2  True   True     True     True   True     True
# 3  True   True     True     True   True     True
# 4  True   True     True     True   True     True

# %%
df.describe()
# Out:
#            Maths    Science    English       Total    Average
# count   5.000000   5.000000   5.000000    5.000000   5.000000
# mean   85.000000  80.400000  84.600000  250.000000  83.333333
# std     7.905694  13.049904   7.635444   18.533753   6.177918
# min    75.000000  65.000000  75.000000  230.000000  76.666667
# 25%    80.000000  68.000000  80.000000  241.000000  80.333333
# 50%    85.000000  85.000000  85.000000  242.000000  80.666667
# 75%    90.000000  92.000000  88.000000  260.000000  86.666667
# max    95.000000  92.000000  95.000000  277.000000  92.333333

# %%
df.shape
# Out:
# (5, 6)

# %%
df.columns
# Out:
# Index(['Name', 'Maths', 'Science', 'English', 'Total', 'Average'], dtype='object')

# %%
df.dtypes
# Out:
# Name        object
# Maths        int64
# Science      int64
# English      int64
# Total        int64
# Average    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name       0
# Maths      0
# Science    0
# English    0
# Total      0
# Average    0
# dtype: int64

# %%
df["Maths"].mean()
# Out:
# np.float64(85.0)

# %%
df["Maths"].median()
# Out:
# 85.0

# %%
df["Maths"].mode()
# Out:
# 0    75
# 1    80
# 2    85
# 3    90
# 4    95
# Name: Maths, dtype: int64

# %%
df["Maths"].max()
# Out:
# 95

# %%
df["Maths"].min()
# Out:
# 75

# %%
df["Maths"].sum()
# Out:
# np.int64(425)

# %%
df["Maths"].count()
# Out:
# np.int64(5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Maths    5 non-null      int64
#  2   Science  5 non-null      int64
#  3   English  5 non-null      int64
#  4   Total    5 non-null      int64
#  5   Average  5 non-null      float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 372.0+ bytes

# %%
df.drop(columns=["Average"])
# Out:
#        Name  Maths  Science  English  Total
# 0     nitin     95       85       80    260
# 1  samridhi     90       92       95    277
# 2    alisha     85       68       88    241
# 3  barinder     80       65       85    230
# 4     arman     75       92       75    242

# %%
plt.plot(df["Maths"])
plt.title("maths marks")
plt.xlabel("student")
plt.ylabel("marks")
plt.show()

# %%
df["Maths"].value_counts().plot(kind ="pie")
plt.show()

# %%
df["Maths"].value_counts().plot(kind ="bar")
plt.show()

# %%
df["Maths"].value_counts().plot(kind ="hist")
plt.show()

# %%
df["English"].value_counts().plot(kind ="box")
plt.show()

# %%
df["Maths"].value_counts().plot(kind ="area")
plt.show()

# %%
plt.plot(df["Maths"])
plt.show()

# %%
plt.scatter(df["Maths"] , df["English"])
plt.show()

# %%
plt.stem(df["Maths"],df["English"])
plt.title("stem plot")
plt.show()

# %%
plt.step(df["Maths"],df["English"])
plt.title("step plot")
plt.show()

# %%
plt.fill_between(df["Maths"],df["English"])
plt.title("Area plot")
plt.show()

# %%
error =[1,2,1,3,2]

# %%
plt.errorbar(df["Maths"],df["English"],
             yerr = error)
plt.title("Error plot")
plt.show()
