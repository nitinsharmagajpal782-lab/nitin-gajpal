# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("m.csv")

# %%
df.head()
# Out:
#          round  gameweek dayofweek        date start_time       home_team  \
# 0  Group stage         1       Thu  2026-06-11      13:00          Mexico
# 1  Group stage         1       Thu  2026-06-11      20:00  Korea Republic
# 2  Group stage         1       Fri  2026-06-12      15:00          Canada
# 3  Group stage         1       Fri  2026-06-12      18:00   United States
# 4  Group stage         1       Sat  2026-06-13      12:00           Qatar
#
#         away_team score  home_score  away_score  ... away_fouls home_corners  \
# 0    South Africa   2–0           2           0  ...         11            3
# 1         Czechia   2–1           2           1  ...         16            4
# 2  Bosnia & Herz.   1–1           1           1  ...         20            9
# 3        Paraguay   4–1           4           1  ...         17            3
# 4     Switzerland   1–1           1           1  ...         11            3
#
# ...

# %%
df.tail()
# Out:
#           round  gameweek dayofweek        date start_time    home_team  \
# 31  Group stage         2       Fri  2026-06-19      20:30       Brazil
# 32  Group stage         2       Sat  2026-06-20      12:00  Netherlands
# 33  Group stage         2       Sat  2026-06-20      16:00      Germany
# 34  Group stage         2       Sat  2026-06-20      19:00      Ecuador
# 35  Group stage         2       Sat  2026-06-20      22:00      Tunisia
#
#         away_team score  home_score  away_score  ... away_fouls home_corners  \
# 31          Haiti   3–0           3           0  ...         14            4
# 32         Sweden   5–1           5           1  ...         12            2
# 33  Côte d'Ivoire   2–1           2           1  ...          7            8
# 34        Curaçao   0–0           0           0  ...         10            9
# 35          Japan   0–4           0           4  ...         15            3
#
#    away_corners home_crosses away_crosses home_interceptions  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   round               36 non-null     object
#  1   gameweek            36 non-null     int64
#  2   dayofweek           36 non-null     object
#  3   date                36 non-null     object
#  4   start_time          36 non-null     object
#  5   home_team           36 non-null     object
#  6   away_team           36 non-null     object
#  7   score               36 non-null     object
#  8   home_score          36 non-null     int64
#  9   away_score          36 non-null     int64
#  10  attendance          36 non-null     object
#  11  venue               36 non-null     object
#  12  referee             36 non-null     object
#  13  home_formation      36 non-null     object
#  14  away_formation      36 non-null     object
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of           round  gameweek dayofweek        date start_time       home_team  \
# 0   Group stage         1       Thu  2026-06-11      13:00          Mexico
# 1   Group stage         1       Thu  2026-06-11      20:00  Korea Republic
# 2   Group stage         1       Fri  2026-06-12      15:00          Canada
# 3   Group stage         1       Fri  2026-06-12      18:00   United States
# 4   Group stage         1       Sat  2026-06-13      12:00           Qatar
# 5   Group stage         1       Sat  2026-06-13      18:00          Brazil
# 6   Group stage         1       Sat  2026-06-13      21:00           Haiti
# 7   Group stage         1       Sat  2026-06-13      21:00       Australia
# 8   Group stage         1       Sun  2026-06-14      12:00         Germany
# 9   Group stage         1       Sun  2026-06-14      15:00     Netherlands
# 10  Group stage         1       Sun  2026-06-14      19:00   Côte d'Ivoire
# ...

# %%
df.isnull().sum()
# Out:
# round                  0
# gameweek               0
# dayofweek              0
# date                   0
# start_time             0
# home_team              0
# away_team              0
# score                  0
# home_score             0
# away_score             0
# attendance             0
# venue                  0
# referee                0
# home_formation         0
# away_formation         0
# home_manager           0
# away_manager           0
# home_captain           0
# away_captain           0
# home_possession        0
# away_possession        0
# home_sot               0
# away_sot               0
# home_total_shots       0
# away_total_shots       0
# home_saves             0
# away_saves             0
# home_cards_yellow      0
# away_cards_yellow      0
# home_cards_red         0
# away_cards_red         0
# home_fouls             0
# away_fouls             0
# home_corners           0
# away_corners           0
# home_crosses           0
# away_crosses           0
# ...

# %%
df.notnull()
# Out:
#     round  gameweek  dayofweek  date  start_time  home_team  away_team  score  \
# 0    True      True       True  True        True       True       True   True
# 1    True      True       True  True        True       True       True   True
# 2    True      True       True  True        True       True       True   True
# 3    True      True       True  True        True       True       True   True
# 4    True      True       True  True        True       True       True   True
# 5    True      True       True  True        True       True       True   True
# 6    True      True       True  True        True       True       True   True
# 7    True      True       True  True        True       True       True   True
# 8    True      True       True  True        True       True       True   True
# 9    True      True       True  True        True       True       True   True
# 10   True      True       True  True        True       True       True   True
# ...

# %%
df.describe()
# Out:
#         gameweek  home_score  away_score  home_possession  away_possession  \
# count  36.000000   36.000000   36.000000        36.000000        36.000000
# mean    1.333333    2.027778    1.000000        53.777778        46.305556
# std     0.478091    1.780628    1.014185        13.627936        13.593737
# min     1.000000    0.000000    0.000000        28.000000        21.000000
# 25%     1.000000    1.000000    0.000000        41.750000        38.000000
# 50%     1.000000    1.500000    1.000000        54.000000        46.000000
# 75%     2.000000    3.000000    1.000000        62.000000        58.250000
# max     2.000000    7.000000    4.000000        79.000000        72.000000
#
#         home_sot   away_sot  home_total_shots  away_total_shots  home_saves  \
# count  36.000000  36.000000         36.000000         36.000000   36.000000
# mean    5.027778   3.388889         13.861111         10.916667    2.416667
# ...

# %%
df.columns
# Out:
# Index(['round', 'gameweek', 'dayofweek', 'date', 'start_time', 'home_team',
#        'away_team', 'score', 'home_score', 'away_score', 'attendance', 'venue',
#        'referee', 'home_formation', 'away_formation', 'home_manager',
#        'away_manager', 'home_captain', 'away_captain', 'home_possession',
#        'away_possession', 'home_sot', 'away_sot', 'home_total_shots',
#        'away_total_shots', 'home_saves', 'away_saves', 'home_cards_yellow',
#        'away_cards_yellow', 'home_cards_red', 'away_cards_red', 'home_fouls',
#        'away_fouls', 'home_corners', 'away_corners', 'home_crosses',
#        'away_crosses', 'home_interceptions', 'away_interceptions',
#        'home_offsides', 'away_offsides', 'notes'],
#       dtype='object')

# %%
df.shape
# Out:
# (36, 42)

# %%
df["away_crosses"].mean()
# Out:
# np.float64(13.805555555555555)

# %%
df["away_crosses"].median()
# Out:
# 12.5

# %%
df["away_crosses"].mode()
# Out:
# 0     9
# 1    15
# Name: away_crosses, dtype: int64

# %%
df["away_crosses"].max()
# Out:
# 47

# %%
df["away_crosses"].min()
# Out:
# 1

# %%
df["away_crosses"].sum()
# Out:
# np.int64(497)

# %%
df["away_crosses"].count()
# Out:
# np.int64(36)

# %%
df["away_crosses"].std()
# Out:
# 8.808500584076869

# %%
df.fillna(0)
# Out:
#           round  gameweek dayofweek        date start_time       home_team  \
# 0   Group stage         1       Thu  2026-06-11      13:00          Mexico
# 1   Group stage         1       Thu  2026-06-11      20:00  Korea Republic
# 2   Group stage         1       Fri  2026-06-12      15:00          Canada
# 3   Group stage         1       Fri  2026-06-12      18:00   United States
# 4   Group stage         1       Sat  2026-06-13      12:00           Qatar
# 5   Group stage         1       Sat  2026-06-13      18:00          Brazil
# 6   Group stage         1       Sat  2026-06-13      21:00           Haiti
# 7   Group stage         1       Sat  2026-06-13      21:00       Australia
# 8   Group stage         1       Sun  2026-06-14      12:00         Germany
# 9   Group stage         1       Sun  2026-06-14      15:00     Netherlands
# 10  Group stage         1       Sun  2026-06-14      19:00   Côte d'Ivoire
# ...

# %%
df.fillna("unknown")
# Out:
#           round  gameweek dayofweek        date start_time       home_team  \
# 0   Group stage         1       Thu  2026-06-11      13:00          Mexico
# 1   Group stage         1       Thu  2026-06-11      20:00  Korea Republic
# 2   Group stage         1       Fri  2026-06-12      15:00          Canada
# 3   Group stage         1       Fri  2026-06-12      18:00   United States
# 4   Group stage         1       Sat  2026-06-13      12:00           Qatar
# 5   Group stage         1       Sat  2026-06-13      18:00          Brazil
# 6   Group stage         1       Sat  2026-06-13      21:00           Haiti
# 7   Group stage         1       Sat  2026-06-13      21:00       Australia
# 8   Group stage         1       Sun  2026-06-14      12:00         Germany
# 9   Group stage         1       Sun  2026-06-14      15:00     Netherlands
# 10  Group stage         1       Sun  2026-06-14      19:00   Côte d'Ivoire
# ...

# %%
df["away_crosses"].fillna(df["away_crosses"].mean())
# Out:
# 0      8
# 1     15
# 2     10
# 3      5
# 4     35
# 5     15
# 6     14
# 7     26
# 8      7
# 9     23
# 10    14
# 11    13
# 12    13
# 13     4
# 14    12
# 15    47
# 16     9
# 17    17
# 18     8
# 19    15
# 20     9
# 21    13
# 22    21
# 23    15
# 24    17
# 25    12
# 26     3
# 27     9
# 28    19
# 29    10
# 30     6
# 31    11
# 32    21
# 33     9
# 34     1
# 35    11
# Name: away_crosses, dtype: int64

# %%
df["away_crosses"].fillna(df["away_crosses"].median())
# Out:
# 0      8
# 1     15
# 2     10
# 3      5
# 4     35
# 5     15
# 6     14
# 7     26
# 8      7
# 9     23
# 10    14
# 11    13
# 12    13
# 13     4
# 14    12
# 15    47
# 16     9
# 17    17
# 18     8
# 19    15
# 20     9
# 21    13
# 22    21
# 23    15
# 24    17
# 25    12
# 26     3
# 27     9
# 28    19
# 29    10
# 30     6
# 31    11
# 32    21
# 33     9
# 34     1
# 35    11
# Name: away_crosses, dtype: int64

# %%
df["away_crosses"].fillna(df["away_crosses"].mode()[0])
# Out:
# 0      8
# 1     15
# 2     10
# 3      5
# 4     35
# 5     15
# 6     14
# 7     26
# 8      7
# 9     23
# 10    14
# 11    13
# 12    13
# 13     4
# 14    12
# 15    47
# 16     9
# 17    17
# 18     8
# 19    15
# 20     9
# 21    13
# 22    21
# 23    15
# 24    17
# 25    12
# 26     3
# 27     9
# 28    19
# 29    10
# 30     6
# 31    11
# 32    21
# 33     9
# 34     1
# 35    11
# Name: away_crosses, dtype: int64

# %%
df.dtypes
# Out:
# round                  object
# gameweek                int64
# dayofweek              object
# date                   object
# start_time             object
# home_team              object
# away_team              object
# score                  object
# home_score              int64
# away_score              int64
# attendance             object
# venue                  object
# referee                object
# home_formation         object
# away_formation         object
# home_manager           object
# away_manager           object
# home_captain           object
# away_captain           object
# home_possession         int64
# away_possession         int64
# home_sot                int64
# away_sot                int64
# home_total_shots        int64
# away_total_shots        int64
# home_saves              int64
# away_saves              int64
# home_cards_yellow       int64
# away_cards_yellow       int64
# home_cards_red          int64
# away_cards_red          int64
# ...

# %%
df[df["away_crosses"]>20]
# Out:
#           round  gameweek dayofweek        date start_time     home_team  \
# 4   Group stage         1       Sat  2026-06-13      12:00         Qatar
# 7   Group stage         1       Sat  2026-06-13      21:00     Australia
# 9   Group stage         1       Sun  2026-06-14      15:00   Netherlands
# 15  Group stage         1       Mon  2026-06-15      18:00  Saudi Arabia
# 22  Group stage         1       Wed  2026-06-17      19:00         Ghana
# 32  Group stage         2       Sat  2026-06-20      12:00   Netherlands
#
#       away_team score  home_score  away_score  ... away_fouls home_corners  \
# 4   Switzerland   1–1           1           1  ...         11            3
# 7       Türkiye   2–0           2           0  ...          4            5
# 9         Japan   2–2           2           2  ...          7            5
# 15      Uruguay   1–1           1           1  ...          6            4
# 22       Panama   1–0           1           0  ...         11            2
# ...

# %%
df[df["away_crosses"]<20]
# Out:
#           round  gameweek dayofweek        date start_time       home_team  \
# 0   Group stage         1       Thu  2026-06-11      13:00          Mexico
# 1   Group stage         1       Thu  2026-06-11      20:00  Korea Republic
# 2   Group stage         1       Fri  2026-06-12      15:00          Canada
# 3   Group stage         1       Fri  2026-06-12      18:00   United States
# 5   Group stage         1       Sat  2026-06-13      18:00          Brazil
# 6   Group stage         1       Sat  2026-06-13      21:00           Haiti
# 8   Group stage         1       Sun  2026-06-14      12:00         Germany
# 10  Group stage         1       Sun  2026-06-14      19:00   Côte d'Ivoire
# 11  Group stage         1       Sun  2026-06-14      20:00          Sweden
# 12  Group stage         1       Mon  2026-06-15      12:00         Belgium
# 13  Group stage         1       Mon  2026-06-15      12:00           Spain
# ...

# %%
df.loc[0]
# Out:
# round                               Group stage
# gameweek                                      1
# dayofweek                                   Thu
# date                                 2026-06-11
# start_time                                13:00
# home_team                                Mexico
# away_team                          South Africa
# score                                       2–0
# home_score                                    2
# away_score                                    0
# attendance                               80,824
# venue                 Estadio Banorte, Coyoacán
# referee                          Wilton Sampaio
# home_formation                          4-1-4-1
# away_formation                            5-3-2
# home_manager                     Javier Aguirre
# away_manager                         Hugo Broos
# home_captain                       César Montes
# away_captain                    Ronwen Williams
# home_possession                              61
# ...

# %%
df.iloc[0]
# Out:
# round                               Group stage
# gameweek                                      1
# dayofweek                                   Thu
# date                                 2026-06-11
# start_time                                13:00
# home_team                                Mexico
# away_team                          South Africa
# score                                       2–0
# home_score                                    2
# away_score                                    0
# attendance                               80,824
# venue                 Estadio Banorte, Coyoacán
# referee                          Wilton Sampaio
# home_formation                          4-1-4-1
# away_formation                            5-3-2
# home_manager                     Javier Aguirre
# away_manager                         Hugo Broos
# home_captain                       César Montes
# away_captain                    Ronwen Williams
# home_possession                              61
# ...

# %%
df.drop("away_crosses",axis=1, inplace=True)\
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.drop("away_crosses",axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...
