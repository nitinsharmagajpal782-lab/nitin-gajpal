# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("l.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1303, step=1)

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.values
# Out:
# array([[0, 'Apple', 'Ultrabook', ..., 'macOS', '1.37kg', 71378.6832],
#        [1, 'Apple', 'Ultrabook', ..., 'macOS', '1.34kg', 47895.5232],
#        [2, 'HP', 'Notebook', ..., 'No OS', '1.86kg', 30636.0],
#        ...,
#        [1300, 'Lenovo', 'Notebook', ..., 'Windows 10', '1.5kg', 12201.12],
#        [1301, 'HP', 'Notebook', ..., 'Windows 10', '2.19kg', 40705.92],
#        [1302, 'Asus', 'Notebook', ..., 'Windows 10', '2.2kg', 19660.32]],
#       shape=(1303, 12), dtype=object)

# %%
df.size
# Out:
# 15636

# %%
df.ndim
# Out:
# 2

# %%
df.sample(5)
# Out:
#      Unnamed: 0 Company   TypeName  Inches  \
# 120         120    Acer   Notebook    15.6
# 59           59    Asus   Notebook    15.6
# 86           86      HP  Ultrabook    15.6
# 118         118    Asus   Notebook    17.3
# 453         453  Lenovo   Notebook    14.0
#
#                               ScreenResolution                         Cpu  \
# 120  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i3 7100U 2.4GHz
# 59                           Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 86                 IPS Panel Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 118                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 453                          Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
#
#      Ram     Memory                       Gpu       OpSys  Weight     Price
# 120  6GB    1TB HDD     Intel HD Graphics 620  Windows 10   2.1kg  25521.12
# 59   4GB  256GB SSD     Intel HD Graphics 520       Linux     2kg  22111.20
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0  Company  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# 0          False    False     False   False             False  False  False
# 1          False    False     False   False             False  False  False
# 2          False    False     False   False             False  False  False
# 3          False    False     False   False             False  False  False
# 4          False    False     False   False             False  False  False
# ...          ...      ...       ...     ...               ...    ...    ...
# 1298       False    False     False   False             False  False  False
# 1299       False    False     False   False             False  False  False
# 1300       False    False     False   False             False  False  False
# 1301       False    False     False   False             False  False  False
# 1302       False    False     False   False             False  False  False
#
#       Memory    Gpu  OpSys  Weight  Price
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.notnull()
# Out:
#       Unnamed: 0  Company  TypeName  Inches  ScreenResolution   Cpu   Ram  \
# 0           True     True      True    True              True  True  True
# 1           True     True      True    True              True  True  True
# 2           True     True      True    True              True  True  True
# 3           True     True      True    True              True  True  True
# 4           True     True      True    True              True  True  True
# ...          ...      ...       ...     ...               ...   ...   ...
# 1298        True     True      True    True              True  True  True
# 1299        True     True      True    True              True  True  True
# 1300        True     True      True    True              True  True  True
# 1301        True     True      True    True              True  True  True
# 1302        True     True      True    True              True  True  True
#
#       Memory   Gpu  OpSys  Weight  Price
# ...

# %%
df.notnull().sum()
# Out:
# Unnamed: 0          1303
# Company             1303
# TypeName            1303
# Inches              1303
# ScreenResolution    1303
# Cpu                 1303
# Ram                 1303
# Memory              1303
# Gpu                 1303
# OpSys               1303
# Weight              1303
# Price               1303
# dtype: int64

# %%
df.drop('ScreenResolution',axis =1)
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# ...

# %%
df.sort_values('Company')
# Out:
#       Unnamed: 0 Company   TypeName  Inches             ScreenResolution  \
# 651          651    Acer     Gaming    15.6            Full HD 1920x1080
# 78            78    Acer   Notebook    15.6            Full HD 1920x1080
# 324          324    Acer   Notebook    15.6                     1366x768
# 326          326    Acer   Notebook    15.6                     1366x768
# 371          371    Acer   Notebook    15.6                     1366x768
# ...          ...     ...        ...     ...                          ...
# 1120        1120    Vero   Notebook    13.3            Full HD 1920x1080
# 877          877  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 184          184  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 514          514  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 192          192  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram              Memory  \
# ...

# %%
df.loc[5]
# Out:
# Unnamed: 0                                5
# Company                                Acer
# TypeName                           Notebook
# Inches                                 15.6
# ScreenResolution                   1366x768
# Cpu                 AMD A9-Series 9420 3GHz
# Ram                                     4GB
# Memory                            500GB HDD
# Gpu                           AMD Radeon R5
# OpSys                            Windows 10
# Weight                                2.1kg
# Price                               21312.0
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# Unnamed: 0                                5
# Company                                Acer
# TypeName                           Notebook
# Inches                                 15.6
# ScreenResolution                   1366x768
# Cpu                 AMD A9-Series 9420 3GHz
# Ram                                     4GB
# Memory                            500GB HDD
# Gpu                           AMD Radeon R5
# OpSys                            Windows 10
# Weight                                2.1kg
# Price                               21312.0
# Name: 5, dtype: object

# %%
df.fillna('unknown')
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df['Cpu'] = df['Cpu'].fillna('Intel Core i5 1.8GHz')
print(df['Cpu'].isnull().sum())
# Out:
# 0

# %%
df = df.sample(5)

# %%
plt.plot(df["Company"],df["Inches"])
plt.title("laptop")
plt.xlabel("Company")
plt.ylabel("Inches")
plt.show()

# %%
df["Company"].value_counts().plot(kind="pie")
plt.show()

# %%
df["Inches"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Inches"].value_counts().plot(kind="pie")
plt.show()

# %%
plt.scatter(df['Inches'], df['Company'])
plt.xlabel('Inches')
plt.ylabel('Company')
plt.title('Laptop Inches vs Price')
plt.show()

# %%
df["Inches"].value_counts().plot(kind="box")
plt.show()

# %%
df["Inches"].value_counts().plot(kind="hist")
plt.show()

# %%
plt.plot(df['Company'], df['Price'])
plt.xlabel('Price')
plt.ylabel('Company')
plt.title('Laptop Inches vs Price')
plt.show()

# %%
plt.barh(df['Company'], df['Price'])
plt.xlabel('Price')
plt.ylabel('Company')
plt.title('Laptop Prices')
plt.show()

# %%
company_counts = df['Company'].value_counts()

plt.pie(company_counts,
        labels=company_counts.index,
        autopct='%1.1f%%')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),
            annot=True)
plt.show()

# %%
sns.pairplot(df[['Inches', 'Weight', 'Price']])
plt.show()

# %%
sns.violinplot(x='Company', y='Price', data=df)
plt.show()

# %%
sns.countplot(x='Company', data=df)
plt.show()

# %%
plt.stem(df['Inches'], df['Price'])
plt.show()

# %%
plt.step(df['Inches'], df['Price'])
plt.show()

# %%
print(df)
# Out:
#      Unnamed: 0  Company     TypeName  Inches  \
# 950         950       HP  Workstation    15.6
# 368         368     Dell     Notebook    15.6
# 883         883   Lenovo     Notebook    15.6
# 507         507     Acer     Notebook    15.6
# 698         698  Toshiba    Ultrabook    13.3
#
#                     ScreenResolution                          Cpu   Ram  \
# 950      IPS Panel Full HD 1920x1080  Intel Core i7 6820HQ 2.7GHz   8GB
# 368                Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 883      IPS Panel Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
# 507      IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz   4GB
# 698  Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz  16GB
#
#         Memory                    Gpu       OpSys  Weight      Price
# 950    8GB SSD   Nvidia Quadro M1000M  Windows 10   2.0kg  119826.72
# 368  256GB SSD     AMD Radeon R7 M445  Windows 10  2.33kg   47898.72
# ...

# %%
print(df[:5])
# Out:
#      Unnamed: 0  Company     TypeName  Inches  \
# 950         950       HP  Workstation    15.6
# 368         368     Dell     Notebook    15.6
# 883         883   Lenovo     Notebook    15.6
# 507         507     Acer     Notebook    15.6
# 698         698  Toshiba    Ultrabook    13.3
#
#                     ScreenResolution                          Cpu   Ram  \
# 950      IPS Panel Full HD 1920x1080  Intel Core i7 6820HQ 2.7GHz   8GB
# 368                Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 883      IPS Panel Full HD 1920x1080   Intel Core i7 6500U 2.5GHz   8GB
# 507      IPS Panel Full HD 1920x1080   Intel Core i5 8250U 1.6GHz   4GB
# 698  Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz  16GB
#
#         Memory                    Gpu       OpSys  Weight      Price
# 950    8GB SSD   Nvidia Quadro M1000M  Windows 10   2.0kg  119826.72
# 368  256GB SSD     AMD Radeon R7 M445  Windows 10  2.33kg   47898.72
# ...

# %%
print(len(df))
# Out:
# 5

# %%
print(df.shape)
# Out:
# (5, 12)

# %%
mean_Price = np.mean(Price)
print("mean :",mean_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[231], line 1
# ----> 1 mean_Price = np.mean(Price)
#       2 print("mean :",mean_price)
#
# NameError: name 'Price' is not defined
