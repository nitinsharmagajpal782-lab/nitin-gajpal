# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("H.csv")

# %%
df.head()
# Out:
#    patient_id  age  gender   chest_pain_type  resting_bp  cholesterol  \
# 0           1   59    Male      Asymptomatic       105.0        154.0
# 1           2   50    Male  Non-anginal Pain       102.0        180.0
# 2           3   61    Male   Atypical Angina       117.0        213.0
# 3           4   73  Female   Atypical Angina       121.0        208.0
# 4           5   49    Male  Non-anginal Pain       106.0        157.0
#
#    fasting_blood_sugar       resting_ecg  max_heart_rate  exercise_angina  \
# 0                  0.0  ST-T Abnormality           186.0                1
# 1                  0.0            Normal           183.0                0
# 2                  1.0            Normal           161.0                0
# 3                  1.0            Normal           150.0                0
# 4                  0.0            Normal           185.0                0
#
#    ...  num_major_vessels        thalassemia   bmi smoking_status  \
# ...

# %%
df.tail()
# Out:
#       patient_id  age  gender   chest_pain_type  resting_bp  cholesterol  \
# 6995        6996   48  Female   Atypical Angina       108.0        127.0
# 6996        6997   63    Male  Non-anginal Pain       107.0        194.0
# 6997        6998   45    Male      Asymptomatic        98.0        119.0
# 6998        6999   52  Female   Atypical Angina       126.0        195.0
# 6999        7000   58  Female  Non-anginal Pain       113.0        172.0
#
#       fasting_blood_sugar                   resting_ecg  max_heart_rate  \
# 6995                  1.0                           NaN           167.0
# 6996                  0.0  Left Ventricular Hypertrophy           159.0
# 6997                  0.0  Left Ventricular Hypertrophy           161.0
# 6998                  0.0              ST-T Abnormality           172.0
# 6999                  1.0                        Normal           146.0
#
#       exercise_angina  ...  num_major_vessels   thalassemia   bmi  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           7000 non-null   int64
#  1   age                  7000 non-null   int64
#  2   gender               7000 non-null   object
#  3   chest_pain_type      7000 non-null   object
#  4   resting_bp           6720 non-null   float64
#  5   cholesterol          6602 non-null   float64
#  6   fasting_blood_sugar  6804 non-null   float64
#  7   resting_ecg          6801 non-null   object
#  8   max_heart_rate       6721 non-null   float64
#  9   exercise_angina      7000 non-null   int64
#  10  oldpeak              6650 non-null   float64
#  11  st_slope             7000 non-null   object
#  12  num_major_vessels    7000 non-null   int64
#  13  thalassemia          7000 non-null   object
#  14  bmi                  6670 non-null   float64
# ...

# %%
df.describe()
# Out:
#         patient_id          age   resting_bp  cholesterol  \
# count  7000.000000  7000.000000  6720.000000  6602.000000
# mean   3500.500000    51.919857   116.447917   184.647683
# std    2020.870275    13.891205    13.197267    33.180086
# min       1.000000    18.000000    80.000000   100.000000
# 25%    1750.750000    43.000000   107.000000   162.000000
# 50%    3500.500000    52.000000   116.000000   184.000000
# 75%    5250.250000    61.000000   125.000000   207.000000
# max    7000.000000    90.000000   162.000000   316.000000
#
#        fasting_blood_sugar  max_heart_rate  exercise_angina      oldpeak  \
# count          6804.000000     6721.000000      7000.000000  6650.000000
# mean              0.252939      173.942717         0.323714     1.274496
# std               0.434728       15.125315         0.467926     1.055225
# min               0.000000      115.000000         0.000000     0.000000
# 25%               0.000000      164.000000         0.000000     0.500000
# ...

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'chest_pain_type', 'resting_bp',
#        'cholesterol', 'fasting_blood_sugar', 'resting_ecg', 'max_heart_rate',
#        'exercise_angina', 'oldpeak', 'st_slope', 'num_major_vessels',
#        'thalassemia', 'bmi', 'smoking_status', 'alcohol_consumption',
#        'physical_activity', 'family_history', 'diabetes', 'stress_level',
#        'heart_attack_risk'],
#       dtype='object')

# %%
df.shape
# Out:
# (7000, 22)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7000, step=1)

# %%
df.dtypes
# Out:
# patient_id               int64
# age                      int64
# gender                  object
# chest_pain_type         object
# resting_bp             float64
# cholesterol            float64
# fasting_blood_sugar    float64
# resting_ecg             object
# max_heart_rate         float64
# exercise_angina          int64
# oldpeak                float64
# st_slope                object
# num_major_vessels        int64
# thalassemia             object
# bmi                    float64
# smoking_status          object
# alcohol_consumption     object
# physical_activity       object
# family_history           int64
# diabetes                 int64
# stress_level           float64
# heart_attack_risk        int64
# dtype: object

# %%
df.values
# Out:
# array([[1, 59, 'Male', ..., 1, 6.0, 0],
#        [2, 50, 'Male', ..., 0, 8.0, 0],
#        [3, 61, 'Male', ..., 1, 2.0, 1],
#        ...,
#        [6998, 45, 'Male', ..., 0, 1.0, 1],
#        [6999, 52, 'Female', ..., 0, 1.0, 1],
#        [7000, 58, 'Female', ..., 1, nan, 1]],
#       shape=(7000, 22), dtype=object)

# %%
df.size
# Out:
# 154000

# %%
df.ndim
# Out:
# 2

# %%
df.isnull()
# Out:
#       patient_id    age  gender  chest_pain_type  resting_bp  cholesterol  \
# 0          False  False   False            False       False        False
# 1          False  False   False            False       False        False
# 2          False  False   False            False       False        False
# 3          False  False   False            False       False        False
# 4          False  False   False            False       False        False
# ...          ...    ...     ...              ...         ...          ...
# 6995       False  False   False            False       False        False
# 6996       False  False   False            False       False        False
# 6997       False  False   False            False       False        False
# 6998       False  False   False            False       False        False
# 6999       False  False   False            False       False        False
#
#       fasting_blood_sugar  resting_ecg  max_heart_rate  exercise_angina  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# patient_id               0
# age                      0
# gender                   0
# chest_pain_type          0
# resting_bp             280
# cholesterol            398
# fasting_blood_sugar    196
# resting_ecg            199
# max_heart_rate         279
# exercise_angina          0
# oldpeak                350
# st_slope                 0
# num_major_vessels        0
# thalassemia              0
# bmi                    330
# smoking_status         505
# alcohol_consumption    405
# physical_activity      346
# family_history           0
# diabetes                 0
# stress_level           268
# heart_attack_risk        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# patient_id             5
# age                    5
# gender                 5
# chest_pain_type        5
# resting_bp             4
# cholesterol            4
# fasting_blood_sugar    5
# resting_ecg            5
# max_heart_rate         4
# exercise_angina        5
# oldpeak                5
# st_slope               5
# num_major_vessels      5
# thalassemia            5
# bmi                    5
# smoking_status         5
# alcohol_consumption    4
# physical_activity      4
# family_history         5
# diabetes               5
# stress_level           4
# heart_attack_risk      5
# dtype: int64

# %%
df.drop('max_heart_rate',axis =1)
# Out:
#       patient_id  age  gender   chest_pain_type  resting_bp  cholesterol  \
# 0              1   59    Male      Asymptomatic       105.0        154.0
# 1              2   50    Male  Non-anginal Pain       102.0        180.0
# 2              3   61    Male   Atypical Angina       117.0        213.0
# 3              4   73  Female   Atypical Angina       121.0        208.0
# 4              5   49    Male  Non-anginal Pain       106.0        157.0
# ...          ...  ...     ...               ...         ...          ...
# 6995        6996   48  Female   Atypical Angina       108.0        127.0
# 6996        6997   63    Male  Non-anginal Pain       107.0        194.0
# 6997        6998   45    Male      Asymptomatic        98.0        119.0
# 6998        6999   52  Female   Atypical Angina       126.0        195.0
# 6999        7000   58  Female  Non-anginal Pain       113.0        172.0
#
#       fasting_blood_sugar                   resting_ecg  exercise_angina  \
# ...

# %%
df.loc[5]
# Out:
# patient_id                            6
# age                                  49
# gender                           Female
# chest_pain_type        Non-anginal Pain
# resting_bp                        128.0
# cholesterol                       195.0
# fasting_blood_sugar                 0.0
# resting_ecg                      Normal
# max_heart_rate                    147.0
# exercise_angina                       0
# oldpeak                             1.4
# st_slope                           Flat
# num_major_vessels                     2
# thalassemia                      Normal
# bmi                                23.3
# smoking_status                   Former
# alcohol_consumption            Moderate
# physical_activity              Moderate
# family_history                        1
# diabetes                              0
# stress_level                        9.0
# heart_attack_risk                     0
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# patient_id                            6
# age                                  49
# gender                           Female
# chest_pain_type        Non-anginal Pain
# resting_bp                        128.0
# cholesterol                       195.0
# fasting_blood_sugar                 0.0
# resting_ecg                      Normal
# max_heart_rate                    147.0
# exercise_angina                       0
# oldpeak                             1.4
# st_slope                           Flat
# num_major_vessels                     2
# thalassemia                      Normal
# bmi                                23.3
# smoking_status                   Former
# alcohol_consumption            Moderate
# physical_activity              Moderate
# family_history                        1
# diabetes                              0
# stress_level                        9.0
# heart_attack_risk                     0
# Name: 5, dtype: object

# %%
df.fillna('unknown')
# Out:
#       patient_id  age  gender   chest_pain_type resting_bp cholesterol  \
# 0              1   59    Male      Asymptomatic      105.0       154.0
# 1              2   50    Male  Non-anginal Pain      102.0       180.0
# 2              3   61    Male   Atypical Angina      117.0       213.0
# 3              4   73  Female   Atypical Angina      121.0       208.0
# 4              5   49    Male  Non-anginal Pain      106.0       157.0
# ...          ...  ...     ...               ...        ...         ...
# 6995        6996   48  Female   Atypical Angina      108.0       127.0
# 6996        6997   63    Male  Non-anginal Pain      107.0       194.0
# 6997        6998   45    Male      Asymptomatic       98.0       119.0
# 6998        6999   52  Female   Atypical Angina      126.0       195.0
# 6999        7000   58  Female  Non-anginal Pain      113.0       172.0
#
#      fasting_blood_sugar                   resting_ecg max_heart_rate  \
# ...

# %%
df = df.sample(5)

# %%
plt.plot(df["age"],df["max_heart_rate"])
plt.title("HEART_RATE")
plt.xlabel("age")
plt.ylabel("max_heart_rate")
plt.show()

# %%
df["gender"].value_counts().plot(kind="pie")
plt.show()
df["age"].value_counts().plot(kind="pie")
plt.show()
df["max_heart_rate"].value_counts().plot(kind="pie")
plt.show()

# %%
df["max_heart_rate"].value_counts().plot(kind="bar")
plt.show()
df["cholesterol"].value_counts().plot(kind="bar")
plt.show()

# %%
plt.scatter(df['cholesterol'], df['max_heart_rate'])
plt.xlabel('cholesterol')
plt.ylabel('max_heart_rate')
plt.title('heart Attak')
plt.show()

# %%
plt.scatter(df['age'], df['resting_bp'])
plt.xlabel('age')
plt.ylabel('resting_bp')
plt.title('health')
plt.show()

# %%
plt.barh(df['age'], df['resting_bp'])
plt.xlabel('age')
plt.ylabel('resting_bp')
plt.title('health')
plt.show()

# %%
df["max_heart_rate"].value_counts().plot(kind="box")
plt.show()

# %%
df["resting_bp"].value_counts().plot(kind="box")
plt.show()

# %%
df["cholesterol"].value_counts().plot(kind="hist")
plt.show()

# %%
gender_counts = df['gender'].value_counts()

plt.pie(gender_counts,
        labels=gender_counts.index,
        autopct='%1.1f%%')
plt.show()

# %%
plt.step(df['age'], df['max_heart_rate'])
plt.show()

# %%
plt.stem(df['age'], df['resting_bp'])
plt.show()

# %%
sns.countplot(x='cholesterol', data=df)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),
            annot=True)
plt.show()

# %%
sns.kdeplot(data=df, x="age" , 
fill=True)
plt.show()

# %%
sns.violinplot(data=df, x="age",
y="cholesterol")
plt.show()

# %%
sns.stripplot(data=df, x="gender",
y="max_heart_rate")
plt.show()

# %%
sns.swarmplot(data=df, x="gender",
y="age")
plt.show()

# %%
sns.pointplot(data=df, x="age", y="smoking_status")
plt.show()

# %%
sns.boxenplot(x="age",y="physical_activity", data=df)
plt.show()

# %%
sns.ecdfplot(data=df, x="stress_level")
plt.show()

# %%
sns.rugplot(data=df, x="age")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.jointplot(data=df, x="age",
y="stress_level" , kind= "scatter")
plt.show()

# %%
sns.lmplot(x="age", y="stress_level", data=df)
plt.show()

# %%
sns.catplot(x="age",y="smoking_status",data=df)
plt.show()

# %%
sns.relplot(x="age",y="stress_level",data=df , kind="scatter")
plt.show()

# %%
sns.displot(data=df, x="age",kde=True)
plt.show()
