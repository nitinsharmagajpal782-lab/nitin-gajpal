# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("delhi.csv")

# %%
df.head()
# Out:
#               DateTime  Locations Parameters  Values Units  hour
# 0  2025-02-18 20:00:00  R K Puram         no    93.2   ppb    20
# 1  2025-02-18 20:15:00  R K Puram         no    90.4   ppb    20
# 2  2025-02-18 21:00:00  R K Puram         no    84.7   ppb    21
# 3  2025-02-18 21:15:00  R K Puram         no    80.8   ppb    21
# 4  2025-02-18 21:30:00  R K Puram         no    81.6   ppb    21

# %%
df.tail()
# Out:
#                     DateTime Locations Parameters   Values Units  hour
# 1214659  2026-05-24 17:00:00      Pusa        nox  0.04588   ppb    17
# 1214660  2026-05-24 17:15:00      Pusa        nox  0.03888   ppb    17
# 1214661  2026-05-24 17:30:00      Pusa        nox  0.04292   ppb    17
# 1214662  2026-05-24 17:45:00      Pusa        nox  0.04042   ppb    17
# 1214663  2026-05-24 18:00:00      Pusa        nox  0.03374   ppb    18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214664 entries, 0 to 1214663
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   DateTime    1214664 non-null  object
#  1   Locations   1214664 non-null  object
#  2   Parameters  1214664 non-null  object
#  3   Values      1212121 non-null  float64
#  4   Units       1214664 non-null  object
#  5   hour        1214664 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 55.6+ MB

# %%
df.shape
# Out:
# (1214664, 6)

# %%
df.columns
# Out:
# Index(['DateTime', 'Locations', 'Parameters', 'Values', 'Units', 'hour'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1214664, step=1)

# %%
df.dtypes
# Out:
# DateTime       object
# Locations      object
# Parameters     object
# Values        float64
# Units          object
# hour            int64
# dtype: object

# %%
df.describe()
# Out:
#              Values          hour
# count  1.212121e+06  1.214664e+06
# mean   5.829616e+01  1.127983e+01
# std    1.410937e+02  6.961739e+00
# min   -9.999000e+03  0.000000e+00
# 25%    1.880000e+00  5.000000e+00
# 50%    2.500000e+01  1.100000e+01
# 75%    7.300000e+01  1.700000e+01
# max    5.183500e+03  2.300000e+01

# %%
df.values
# Out:
# array([['2025-02-18 20:00:00', 'R K Puram', 'no', 93.2, 'ppb', 20],
#        ['2025-02-18 20:15:00', 'R K Puram', 'no', 90.4, 'ppb', 20],
#        ['2025-02-18 21:00:00', 'R K Puram', 'no', 84.7, 'ppb', 21],
#        ...,
#        ['2026-05-24 17:30:00', 'Pusa', 'nox', 0.04292, 'ppb', 17],
#        ['2026-05-24 17:45:00', 'Pusa', 'nox', 0.04042, 'ppb', 17],
#        ['2026-05-24 18:00:00', 'Pusa', 'nox', 0.03374, 'ppb', 18]],
#       shape=(1214664, 6), dtype=object)

# %%
df.size
# Out:
# 7287984

# %%
df.ndim
# Out:
# 2

# %%
df.sample(5)
# Out:
#                    DateTime     Locations   Parameters    Values  Units  hour
# 232868  2025-05-15 19:00:00   Anand Vihar  temperature  31.80000      c    19
# 93405   2025-03-29 18:00:00  Punjabi Bagh           o3  31.80000  µg/m³    18
# 534932  2025-09-11 15:46:00          Pusa           co   0.97033    ppb    15
# 959072  2026-02-28 11:15:00   Anand Vihar           no  20.70000    ppb    11
# 582114  2025-09-27 16:01:00          Pusa           no   8.21558    ppb    16

# %%
df.isnull()
# Out:
#          DateTime  Locations  Parameters  Values  Units   hour
# 0           False      False       False   False  False  False
# 1           False      False       False   False  False  False
# 2           False      False       False   False  False  False
# 3           False      False       False   False  False  False
# 4           False      False       False   False  False  False
# ...           ...        ...         ...     ...    ...    ...
# 1214659     False      False       False   False  False  False
# 1214660     False      False       False   False  False  False
# 1214661     False      False       False   False  False  False
# 1214662     False      False       False   False  False  False
# 1214663     False      False       False   False  False  False
#
# [1214664 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# DateTime         0
# Locations        0
# Parameters       0
# Values        2543
# Units            0
# hour             0
# dtype: int64

# %%
df.notnull()
# Out:
#          DateTime  Locations  Parameters  Values  Units  hour
# 0            True       True        True    True   True  True
# 1            True       True        True    True   True  True
# 2            True       True        True    True   True  True
# 3            True       True        True    True   True  True
# 4            True       True        True    True   True  True
# ...           ...        ...         ...     ...    ...   ...
# 1214659      True       True        True    True   True  True
# 1214660      True       True        True    True   True  True
# 1214661      True       True        True    True   True  True
# 1214662      True       True        True    True   True  True
# 1214663      True       True        True    True   True  True
#
# [1214664 rows x 6 columns]

# %%
df.notnull().sum()
# Out:
# DateTime      1214664
# Locations     1214664
# Parameters    1214664
# Values        1212121
# Units         1214664
# hour          1214664
# dtype: int64

# %%
df.drop('hour',axis =1)
# Out:
#                    DateTime     Locations  Parameters    Values  Units
# 392992  2025-07-20 21:45:00  Punjabi Bagh          o3  10.00000  µg/m³
# 258006  2025-05-17 19:30:00     R K Puram  wind_speed   0.30000    m/s
# 18819   2025-02-28 03:45:00  Punjabi Bagh          co   1.20000    ppb
# 850715  2025-12-13 00:30:00     R K Puram         nox   0.15850    ppb
# 117038  2025-05-10 06:16:00          Pusa          no   8.54194    ppb

# %%
df.sort_values('Company')
# Out:
#       Unnamed: 0 Company   TypeName  Inches             ScreenResolution  \
# 651          651    Acer     Gaming    15.6            Full HD 1920x1080
# 78            78    Acer   Notebook    15.6            Full HD 1920x1080
# 324          324    Acer   Notebook    15.6                     1366x768
# 326          326    Acer   Notebook    15.6                     1366x768
# 371          371    Acer   Notebook    15.6                     1366x768
# ...          ...     ...        ...     ...                          ...
# 1120        1120    Vero   Notebook    13.3            Full HD 1920x1080
# 877          877  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 184          184  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 514          514  Xiaomi   Notebook    15.6  IPS Panel Full HD 1920x1080
# 192          192  Xiaomi  Ultrabook    13.3  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram              Memory  \
# ...

# %%
df.loc[5]
# Out:
# DateTime      2025-02-18 21:45:00
# Locations               R K Puram
# Parameters                     no
# Values                       94.8
# Units                         ppb
# hour                           21
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# Unnamed: 0                                5
# Company                                Acer
# TypeName                           Notebook
# Inches                                 15.6
# ScreenResolution                   1366x768
# Cpu                 AMD A9-Series 9420 3GHz
# Ram                                     4GB
# Memory                            500GB HDD
# Gpu                           AMD Radeon R5
# OpSys                            Windows 10
# Weight                                2.1kg
# Price                               21312.0
# Name: 5, dtype: object

# %%
df.fillna('unknown')
# Out:
#                     DateTime  Locations Parameters   Values Units  hour
# 0        2025-02-18 20:00:00  R K Puram         no     93.2   ppb    20
# 1        2025-02-18 20:15:00  R K Puram         no     90.4   ppb    20
# 2        2025-02-18 21:00:00  R K Puram         no     84.7   ppb    21
# 3        2025-02-18 21:15:00  R K Puram         no     80.8   ppb    21
# 4        2025-02-18 21:30:00  R K Puram         no     81.6   ppb    21
# ...                      ...        ...        ...      ...   ...   ...
# 1214659  2026-05-24 17:00:00       Pusa        nox  0.04588   ppb    17
# 1214660  2026-05-24 17:15:00       Pusa        nox  0.03888   ppb    17
# 1214661  2026-05-24 17:30:00       Pusa        nox  0.04292   ppb    17
# 1214662  2026-05-24 17:45:00       Pusa        nox  0.04042   ppb    17
# 1214663  2026-05-24 18:00:00       Pusa        nox  0.03374   ppb    18
#
# [1214664 rows x 6 columns]

# %%
df['hour'] = df['hour'].fillna('Locations')
print(df['hour'].isnull().sum())
# Out:
# 0

# %%
df = df.sample(5)

# %%
plt.plot(df["Locations"],df["Values"])
plt.title("AQI")
plt.xlabel("Locations")
plt.ylabel("Values")
plt.show()

# %%
df["Parameters"].value_counts().plot(kind="pie")
plt.show()

# %%
df["Parameters"].value_counts().plot(kind="bar")
plt.show()

# %%
df["Locations"].value_counts().plot(kind="pie")
plt.show()

# %%
plt.scatter(df['Locations'], df['DateTime'])
plt.xlabel('Locations')
plt.ylabel('DateTime')
plt.title('AQI')
plt.show()

# %%
df["Locations"].value_counts().plot(kind="box")
plt.show()

# %%
df["Parameters"].value_counts().plot(kind="hist")
plt.show()

# %%
plt.plot(df['Locations'], df['DateTime'])
plt.xlabel('Locations')
plt.ylabel('DateTime')
plt.title('AQI level')
plt.show()

# %%
plt.barh(df['Locations'], df['DateTime'])
plt.xlabel('Locations')
plt.ylabel('DateTime')
plt.title('AQI level')
plt.show()

# %%
Locations_counts = df['Locations'].value_counts()

plt.pie(Locations_counts,
        labels=Locations_counts.index,
        autopct='%1.1f%%')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),
            annot=True)
plt.show()

# %%
sns.countplot(x='Locations', data=df)
plt.show()

# %%
plt.stem(df['Locations'], df['DateTime'])
plt.show()

# %%
plt.step(df['Locations'], df['DateTime'])
plt.show()

# %%
print(df)
# Out:
#                    DateTime     Locations  Parameters    Values  Units  hour
# 392992  2025-07-20 21:45:00  Punjabi Bagh          o3  10.00000  µg/m³    21
# 258006  2025-05-17 19:30:00     R K Puram  wind_speed   0.30000    m/s    19
# 18819   2025-02-28 03:45:00  Punjabi Bagh          co   1.20000    ppb     3
# 850715  2025-12-13 00:30:00     R K Puram         nox   0.15850    ppb     0
# 117038  2025-05-10 06:16:00          Pusa          no   8.54194    ppb     6

# %%
print(df[:5])
# Out:
#                    DateTime     Locations  Parameters    Values  Units  hour
# 392992  2025-07-20 21:45:00  Punjabi Bagh          o3  10.00000  µg/m³    21
# 258006  2025-05-17 19:30:00     R K Puram  wind_speed   0.30000    m/s    19
# 18819   2025-02-28 03:45:00  Punjabi Bagh          co   1.20000    ppb     3
# 850715  2025-12-13 00:30:00     R K Puram         nox   0.15850    ppb     0
# 117038  2025-05-10 06:16:00          Pusa          no   8.54194    ppb     6

# %%
print(len(df))
# Out:
# 5

# %%
print(df.shape)
# Out:
# (5, 6)

# %%
df["hour"].mean()
# Out:
# np.float64(9.8)

# %%
df["hour"].mode()
# Out:
# 0     0
# 1     3
# 2     6
# 3    19
# 4    21
# Name: hour, dtype: int64

# %%
df["hour"].median()
# Out:
# 6.0
